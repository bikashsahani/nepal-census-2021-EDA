# %% [markdown]
# This is the dataset of Nepal Census 2021..

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("census.csv")

# %%
data
# Out:
#      _id   District                    Local Level Name  Total family number  \
# 0      1  Taplejung  Aathrai Tribeni Rural Municipality                 2869
# 1      2  Taplejung       Maiwakhola Rural Municipality                 2275
# 2      3  Taplejung        Meringden Rural Municipality                 2683
# 3      4  Taplejung       Mikwakhola Rural Municipality                 1862
# 4      5  Taplejung     Phaktanglung Rural Municipality                 2864
# ..   ...        ...                                 ...                  ...
# 748  749   Darchula               Mahakali Municipality                 6080
# 749  750   Darchula      Malikaarjun Rural Municipality                 3241
# 750  751   Darchula            Marma Rural Municipality                 3086
# 751  752   Darchula           Naugad Rural Municipality                 3156
# 752  753   Darchula         Shailyashikhar Municipality                 4561
#
# ...

# %% [markdown]
# Data Understanding (5 questions)
# 1. What are the shape (rows & columns), data types, and basic info of the dataset?

# %%
data.shape
# Out:
# (753, 8)

# %% [markdown]
# our data set have 753 rows and 8 columns

# %%
data.columns
# Out:
# Index(['_id', 'District', 'Local Level Name', 'Total family number',
#        'Total household number', 'Total population', 'Total Male',
#        'Total Female'],
#       dtype='object')

# %% [markdown]
# these are our columns:
#
# id = id number
#
# District = Name of the district
#
# Local Level Name = name of the municipality under the district
#
# Total family number = Total number of families
#
# Total household number = total number of houses
#
# Total population = total number of people
#
# Total Male = total number of male population
#
# Total Female = Total number of female population

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     753 non-null    int64
#  1   District                753 non-null    object
#  2   Local Level Name        753 non-null    object
#  3   Total family number     753 non-null    int64
#  4   Total household number  753 non-null    int64
#  5   Total population        753 non-null    int64
#  6   Total Male              753 non-null    int64
#  7   Total Female            753 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 47.2+ KB

# %% [markdown]
# 2. How many unique Districts and Local Levels are there?

# %%
data['District'].unique()
# Out:
# array(['Taplejung', 'Panchthar', 'Ilam', 'Jhapa', 'Morang', 'Sunsari',
#        'Dhankuta', 'Terhathum', 'Sankhuwasabha', 'Bhojpur', 'Solukhumbu',
#        'Okhaldhunga', 'Khotang', 'Udayapur', 'Saptari', 'Siraha',
#        'Dhanusa', 'Mahottari', 'Sarlahi', 'Rautahat', 'Bara', 'Parsa',
#        'Sindhuli', 'Ramechhap', 'Dolakha', 'Sindhupalchok',
#        'Kavrepalanchok', 'Lalitpur', 'Bhaktapur', 'Kathmandu', 'Nuwakot',
#        'Rasuwa', 'Dhading', 'Makwanpur', 'Chitawan', 'Gorkha', 'Lamjung',
#        'Tanahu', 'Syangja', 'Kaski', 'Manang', 'Mustang', 'Myagdi',
#        'Parbat', 'Baglung', 'Nawalparasi East', 'Gulmi', 'Palpa',
#        'Nawalparasi West', 'Rupandehi', 'Kapilbastu', 'Arghakhanchi',
#        'Pyuthan', 'Rolpa', 'Rukum East', 'Dang', 'Banke', 'Bardiya',
#        'Rukum West', 'Salyan', 'Surkhet', 'Dailekh', 'Jajarkot', 'Dolpa',
#        'Jumla', 'Kalikot', 'Mugu', 'Humla', 'Bajura', 'Bajhang', 'Achham',
# ...

# %%
len(data['District'].unique())
# Out:
# 77

# %% [markdown]
# 77 unique districts

# %%
data["Local Level Name"].unique()
# Out:
# array(['Aathrai Tribeni Rural Municipality',
#        'Maiwakhola Rural Municipality', 'Meringden Rural Municipality',
#        'Mikwakhola Rural Municipality', 'Phaktanglung Rural Municipality',
#        'Phungling Municipality', 'Sidingba Rural Municipality',
#        'Sirijangha Rural Municipality',
#        'Pathivara Yangwarak Rural Municipality',
#        'Falelung Rural Municipality', 'Falgunanda Rural Municipality',
#        'Hilihang Rural Municipality', 'Kummayak Rural Municipality',
#        'Miklajung Rural Municipality', 'Phidim Municipality',
#        'Tumbewa Rural Municipality', 'Yangwarak Rural Municipality',
#        'Chulachuli Rural Municipality', 'Deumai Municipality',
#        'Fakphokthum Rural Municipality', 'Illam Municipality',
#        'Maijogmai Rural Municipality', 'Mai Municipality',
#        'Mangsebung Rural Municipality', 'Rong Rural Municipality',
#        'Sandakpur Rural Municipality', 'Suryodaya Municipality',
# ...

# %%
len(data['Local Level Name'].unique())
# Out:
# 737

# %%
data['Local Level Name'].nunique()
# Out:
# 737

# %% [markdown]
# 737 unique Local level names.

# %% [markdown]
# 3. Are there any missing values or duplicate rows in the dataset?

# %%
data.isnull().sum()
# Out:
# _id                       0
# District                  0
# Local Level Name          0
# Total family number       0
# Total household number    0
# Total population          0
# Total Male                0
# Total Female              0
# dtype: int64

# %% [markdown]
# No, there is no any missing values

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No, their are no duplicate rows.

# %% [markdown]
# 4. What is the summary statistics (mean, median, min, max, std) for numerical columns like Total Population, Total Male, Total Female, etc.?

# %%
data.describe()
# Out:
#               _id  Total family number  Total household number  \
# count  753.000000           753.000000              753.000000
# mean   377.000000          8976.723772             7493.590969
# std    217.516666         12986.552238             8401.892705
# min      1.000000           125.000000              125.000000
# 25%    189.000000          4036.000000             3653.000000
# 50%    377.000000          5896.000000             5195.000000
# 75%    565.000000          9510.000000             8151.000000
# max    753.000000        231714.000000           105649.000000
#
#        Total population     Total Male   Total Female
# count        753.000000     753.000000     753.000000
# mean       38612.204515   18842.814077   19769.390438
# std        49904.377212   24891.928559   25046.362147
# min          398.000000     170.000000     228.000000
# 25%        16768.000000    8115.000000    8553.000000
# 50%        25508.000000   12248.000000   13010.000000
# ...

# %% [markdown]
# 5. What is the range and distribution of Total Family Number and Total Household Number?

# %%
# to find range 
min_family_num = data['Total family number'].min()
max_family_num = data['Total family number'].max()
family_range = max_family_num - min_family_num
print(f"Range of Total family number = {family_range}")

min_household = data['Total household number'].min()
max_household = data['Total household number'].max()
household_range = max_household - min_household
print(f"Range of Total household number = {household_range}")
# Out:
# Range of Total family number = 231589
# Range of Total household number = 105524

# %%
# to find distribution
data['Total family number'].describe()
# Out:
# count       753.000000
# mean       8976.723772
# std       12986.552238
# min         125.000000
# 25%        4036.000000
# 50%        5896.000000
# 75%        9510.000000
# max      231714.000000
# Name: Total family number, dtype: float64

# %%
data["Total household number"].describe()
# Out:
# count       753.000000
# mean       7493.590969
# std        8401.892705
# min         125.000000
# 25%        3653.000000
# 50%        5195.000000
# 75%        8151.000000
# max      105649.000000
# Name: Total household number, dtype: float64

# %% [markdown]
# data Cleaning & Manipulation (5 questions)
#
# 6. Verify data consistency: Does Total Male + Total Female equal Total Population for all rows? If not, how many mismatches?

# %%
data['mismatch']=(data['Total Male'] + data['Total Female']) == data['Total population']
data
# Out:
#      _id   District                    Local Level Name  Total family number  \
# 0      1  Taplejung  Aathrai Tribeni Rural Municipality                 2869
# 1      2  Taplejung       Maiwakhola Rural Municipality                 2275
# 2      3  Taplejung        Meringden Rural Municipality                 2683
# 3      4  Taplejung       Mikwakhola Rural Municipality                 1862
# 4      5  Taplejung     Phaktanglung Rural Municipality                 2864
# ..   ...        ...                                 ...                  ...
# 748  749   Darchula               Mahakali Municipality                 6080
# 749  750   Darchula      Malikaarjun Rural Municipality                 3241
# 750  751   Darchula            Marma Rural Municipality                 3086
# 751  752   Darchula           Naugad Rural Municipality                 3156
# 752  753   Darchula         Shailyashikhar Municipality                 4561
#
# ...

# %%
data[data['mismatch']=='False']
# Out:
# Empty DataFrame
# Columns: [_id, District, Local Level Name, Total family number, Total household number, Total population, Total Male, Total Female, mismatch]
# Index: []

# %% [markdown]
# No, There is no mismatch in the total population. Total Male + Total Female = Total population

# %% [markdown]
# 7. Create new columns: Population Density proxy (if possible), Male Percentage, Female Percentage, and Sex Ratio (Male:Female).

# %%
data['Male percentage'] = ((data['Total Male'] / data['Total population']) * 100).round(2)
data['Female percentage'] = ((data['Total Female'] / data['Total population']) * 100).round(2)
data['Sex Ration'] = (data['Total Male'] / data['Total Female']).round(2)

# Population Density (Average population per household)
data['population density'] = data['Total population'] / data['Total household number']

# %%
data.sample(10)
# Out:
#      _id   District                 Local Level Name  Total family number  \
# 334  335  Kathmandu     Budhanilakantha Municipality                47169
# 603  604    Surkhet          Bheriganga Municipality                11599
# 129  130   Udayapur              Belaka Municipality                12170
# 715  716    Kailali          Lamkichuha Municipality                20801
# 142  143    Saptari  Chhinnamasta Rural Municipality                 6373
# 429  430    Syangja    Phedikhola Rural Municipality                 3222
# 602  603    Surkhet      Barahtal Rural Municipality                 6240
# 204  205  Mahottari        Sonama Rural Municipality                 9252
# 712  713    Kailali        Janaki Rural Municipality                11180
# 389  390   Chitawan                Madi Municipality                10227
#
#      Total household number  Total population  Total Male  Total Female  \
# 334                   26910            179688       89284         90404
# ...

# %% [markdown]
# 8. Group the data by District and calculate aggregate totals (Total Population, Households, Families per district).

# %%
district_summary = data.groupby('District').agg({
    'Total population' : 'sum',
    'Total household number': 'sum',
    'Total family number':'sum'
}).reset_index()
district_summary
# Out:
#         District  Total population  Total household number  \
# 0         Achham            228907                   39368
# 1   Arghakhanchi            176534                   45012
# 2        Baglung            248964                   58445
# 3        Baitadi            244400                   42288
# 4        Bajhang            189023                   32916
# ..           ...               ...                     ...
# 72       Syangja            254277                   62856
# 73        Tanahu            326962                   81642
# 74     Taplejung            120359                   26139
# 75     Terhathum             88885                   20352
# 76      Udayapur            342051                   75932
#
#     Total family number
# 0                 49962
# 1                 49073
# 2                 65334
# 3                 50472
# 4                 38368
# ..                  ...
# 72                70710
# 73                93168
# 74                28530
# ...

# %%
print("Total population = ",district_summary['Total population'].sum())
# Out:
# Total population =  29074990

# %%
district_summary[district_summary['District']=='Bara']
# Out:
#   District  Total population  Total household number  Total family number
# 7     Bara            742667                  112301               134362

# %% [markdown]
# above is the summery of bara district

# %% [markdown]
# 9. Identify and handle any outliers in Total Population or Household counts.

# %%
# outliers for Total population
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
population_q1 = data['Total population'].quantile(0.25)
population_q3 = data['Total population'].quantile(0.75)

# calculate the IQR (Inter Quantile Range)
population_IQR = population_q3-population_q1

# Define outlier boundariesa
population_lower_bound = population_q1 - 1.5 * population_IQR
population_upper_bound = population_q3 + 1.5 * population_IQR

# filtering the rows containing outliers
population_outliers = data[(data['Total population'] < population_lower_bound) | (data['Total population'] > population_upper_bound)]
print(len(population_outliers))

population_median = data['Total population'].median()
# dataFrame.loc[condition, 'Column_Name'] = 'Value'

data.loc[population_outliers.index,'Total population']=population_median

# Check if any value still exceeds your ORIGINAL upper bound
population_outliers = data[((data['Total population'] > population_upper_bound) | (data['Total population']< population_lower_bound))]
print(f"Total population outliers : {len(population_outliers)}") 
# This will output: 0
# Out:
# 49
# Total population outliers : 0

# %%
# outliers for Total household number
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
household_q1 = data['Total household number'].quantile(0.25)
household_q3 = data['Total household number'].quantile(0.75)

# calculate the IQR (Inter Quantile Range)
household_IQR = household_q3 - household_q1

# Define outlier boundaries
household_lower_bound = household_q1 - 1.5 * household_IQR
household_upper_bound = household_q3 +1.5 * household_IQR

# filtering the rows containing outliers
household_outliers = data[(data['Total household number']< household_lower_bound) | (data['Total household number']>household_upper_bound)]
print(len(household_outliers))
household_median = data['Total household number'].median()
# dataFrame.loc[condition, 'Column_Name'] = 'Value'
data.loc[household_outliers.index,'Total household number']=household_median

# Check if any value still exceeds your ORIGINAL upper bound
household_outliers = data[((data['Total population'] > household_upper_bound) | (data['Total population']< household_lower_bound))]
print(f"household  outliers: {len(household_outliers)}")
# Out:
# 65
# household  outliers: 613

# %%
data
# Out:
#      _id   District                    Local Level Name  Total family number  \
# 0      1  Taplejung  Aathrai Tribeni Rural Municipality                 2869
# 1      2  Taplejung       Maiwakhola Rural Municipality                 2275
# 2      3  Taplejung        Meringden Rural Municipality                 2683
# 3      4  Taplejung       Mikwakhola Rural Municipality                 1862
# 4      5  Taplejung     Phaktanglung Rural Municipality                 2864
# ..   ...        ...                                 ...                  ...
# 748  749   Darchula               Mahakali Municipality                 6080
# 749  750   Darchula      Malikaarjun Rural Municipality                 3241
# 750  751   Darchula            Marma Rural Municipality                 3086
# 751  752   Darchula           Naugad Rural Municipality                 3156
# 752  753   Darchula         Shailyashikhar Municipality                 4561
#
# ...

# %% [markdown]
# 10. Create a new feature: Average Family Size (Total Population / Total Family Number) and Average Household Size.

# %%
data['Average family size'] = (data['Total population'] / data['Total family number']).round(2)
data['Average household size'] = (data['Total population'] / data['Total household number']).round(2)
data
# Out:
#      _id   District                    Local Level Name  Total family number  \
# 0      1  Taplejung  Aathrai Tribeni Rural Municipality                 2869
# 1      2  Taplejung       Maiwakhola Rural Municipality                 2275
# 2      3  Taplejung        Meringden Rural Municipality                 2683
# 3      4  Taplejung       Mikwakhola Rural Municipality                 1862
# 4      5  Taplejung     Phaktanglung Rural Municipality                 2864
# ..   ...        ...                                 ...                  ...
# 748  749   Darchula               Mahakali Municipality                 6080
# 749  750   Darchula      Malikaarjun Rural Municipality                 3241
# 750  751   Darchula            Marma Rural Municipality                 3086
# 751  752   Darchula           Naugad Rural Municipality                 3156
# 752  753   Darchula         Shailyashikhar Municipality                 4561
#
# ...

# %% [markdown]
# 3. Descriptive Statistics (4 questions)
#
#     11. What are the top 10 and bottom 10 Local Levels by Total Population?

# %%
data.sort_values(by='Total population', ascending=False).head(10)
# Out:
#      _id          District          Local Level Name  Total family number  \
# 710  711           Kailali   Ghodaghodi Municipality                18636
# 529  530        Kapilbastu     Shivaraj Municipality                16072
# 27    28             Jhapa   Arjundhara Municipality                20978
# 227  228          Rautahat   Chandrapur Municipality                17237
# 207  208           Sarlahi  Barahathawa Municipality                16257
# 42    43            Morang      Belbari Municipality                20662
# 340  341         Kathmandu     Kirtipur Municipality                24211
# 415  416            Tanahu         Byas Municipality                24078
# 473  474  Nawalparasi East     Gaidakot Municipality                20701
# 330  331         Bhaktapur    Bhaktapur Municipality                18854
#
#      Total household number  Total population  Total Male  Total Female  \
# 710                    5195             85982       40223         45759
# ...

# %%
data.sort_values(by='Total population', ascending=False).head(10)['Local Level Name']
# Out:
# 710     Ghodaghodi Municipality
# 529       Shivaraj Municipality
# 27      Arjundhara Municipality
# 227     Chandrapur Municipality
# 207    Barahathawa Municipality
# 42         Belbari Municipality
# 340       Kirtipur Municipality
# 415           Byas Municipality
# 473       Gaidakot Municipality
# 330      Bhaktapur Municipality
# Name: Local Level Name, dtype: object

# %% [markdown]
# these are the top 10 local level name by total population

# %%
data.sort_values(by='Total population',ascending=True).head(10)['Local Level Name']
# Out:
# 438               Narpa Bhumi Rural Municipality
# 437                     Chame Rural Municipality
# 442    Lo-Ghekar Damodarkunda Rural Municipality
# 440          Manang Ingshyang Rural Municipality
# 439                   Narshon Rural Municipality
# 629          Chharka Tangsong Rural Municipality
# 444                Lomanthang Rural Municipality
# 630              Dolpo Buddha Rural Municipality
# 631                 Jagadulla Rural Municipality
# 441     Waragung Muktikhsetra Rural Municipality
# Name: Local Level Name, dtype: object

# %% [markdown]
# these are the bottom 10 local level name by total population

# %% [markdown]
# 12. Which District has the highest and lowest total population?

# %%
district_population = data.groupby('District').agg({
    'Total population':'sum'
}).reset_index()
print(district_population.sort_values('Total population', ascending=True).head(1))
print()
print(district_population.sort_values('Total population', ascending=True).tail(1))
# Out:
#    District  Total population
# 41   Manang              4925
#
#    District  Total population
# 65  Sarlahi            856443

# %% [markdown]
# Manang has the lowest population and Sarlahi has the highest population

# %% [markdown]
# 13. What is the average, median, and total population across all Local Levels?

# %%
total_population = data['Total population'].sum()
avg_population =data['Total population'].mean()
median_population = data['Total population'].median()
print(f"Total population = {(total_population)}")
print(f"Average population = {(avg_population).round(2)}")
print(f"Media population = {(median_population)}")
# Out:
# Total population = 22101620
# Average population = 29351.42
# Media population = 25508.0

# %% [markdown]
# 14. How do Total Family Number and Total Household Number correlate with Total Population?

# %%
data.sample()
# Out:
#      _id District              Local Level Name  Total family number  \
# 208  209  Sarlahi  Basbariya Rural Municipality                 4675
#
#      Total household number  Total population  Total Male  Total Female  \
# 208                    3908             26406       13495         12911
#
#      mismatch  Male percentage  Female percentage  Sex Ration  \
# 208      True            51.11              48.89        1.05
#
#      population density  Average family size  Average household size
# 208            6.756909                 5.65                    6.76

# %%
data[['Total family number','Total household number','Total population']].corr()
# Out:
#                         Total family number  Total household number  \
# Total family number                1.000000                0.236384
# Total household number             0.236384                1.000000
# Total population                   0.253037                0.815717
#
#                         Total population
# Total family number             0.253037
# Total household number          0.815717
# Total population                1.000000

# %% [markdown]
# 4. Visualization (6 questions)
#
#     15. Create a bar chart showing Top 10 Districts by Total Population.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.sort_values(by='Total population', ascending=False).head(10)
# Out:
#      _id          District          Local Level Name  Total family number  \
# 710  711           Kailali   Ghodaghodi Municipality                18636
# 529  530        Kapilbastu     Shivaraj Municipality                16072
# 27    28             Jhapa   Arjundhara Municipality                20978
# 227  228          Rautahat   Chandrapur Municipality                17237
# 207  208           Sarlahi  Barahathawa Municipality                16257
# 42    43            Morang      Belbari Municipality                20662
# 340  341         Kathmandu     Kirtipur Municipality                24211
# 415  416            Tanahu         Byas Municipality                24078
# 473  474  Nawalparasi East     Gaidakot Municipality                20701
# 330  331         Bhaktapur    Bhaktapur Municipality                18854
#
#      Total household number  Total population  Total Male  Total Female  \
# 710                    5195             85982       40223         45759
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(
    data=data.sort_values(by='Total population', ascending=False).head(10),
    x='District',
    y='Total population'
)
plt.xticks(rotation=90,fontsize=14)
plt.xlabel("Top 10 district",fontsize=20)
plt.ylabel("population", fontsize=20)
plt.title("Top 10 District by population", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 10 District by population')

# %% [markdown]
# 16. Plot a histogram and boxplot to show the distribution of Total Population across Local Levels.

# %%
plt.figure(figsize=(12, 6))

sns.histplot(
    data=data,  # Make sure this matches your DataFrame variable name
    x='Total population',
    bins=15,    # Adjust the number of bins based on your total row count
    kde=True,   # Keeps the smooth density estimation line
    color='skyblue'
)

# Rotate the x-axis numbers if they are tight, though 90 might be overkill for a clean x-axis
plt.xticks(rotation=45) 

plt.title('Distribution of Total Population Across Local Levels', fontsize=14, fontweight='bold')
plt.xlabel('Total Population', fontsize=12)
plt.ylabel('Count (Frequency of Local Levels)', fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Fix: Only pass x, remove y. This tells Seaborn to plot a standard 1D histogram.
sns.boxplot(
    data=data, 
    y='Total population', 
    color='lightgreen',
    width=0.4
)

plt.title('Boxplot of Total Population Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Local Levels', fontsize=12)
plt.ylabel('Total Population', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# 17. Create a pie chart showing overall Male vs Female population proportion.

# %%
df=[data['Total Male'].sum(),data['Total Female'].sum()]

# %%
categories=['Male','Female']
plt.figure(figsize=(5,15))
plt.pie(
    df,
    labels=categories,
    colors = sns.color_palette("pastel"),
    autopct='%1.1f%%',     # Show percentages out to 1 decimal point
    startangle=90,         # Rotate starting point to the top
    wedgeprops={'edgecolor': 'white', 'linewidth': 2} # Clean borders
)
plt.title("Overall Male Vs Female")
plt.show()

# %% [markdown]
# female population is greater then male population.

# %% [markdown]
# 18. Visualize Average Family Size distribution across districts using a violin plot.

# %%
# 1. Find the top 10 districts by looking at the head(10) names
top_districts_list = data.sort_values(by='Total population', ascending=False).head(10)['District'].unique()

# 2. Filter the ORIGINAL dataset to include ALL rows belonging to those districts
filtered_data = data[data['District'].isin(top_districts_list)]

plt.figure(figsize=(20, 10))

# 3. Plot using the full data subset so there are enough rows to form violins
sns.violinplot(
    data=filtered_data,
    x='District',
    y='Average family size',
    inner='box',
    palette='muted',
    hue='District'
)

plt.title('Average Family Size Distribution within the Top 10 Most Populated Districts', fontsize=14, fontweight='bold')
plt.xticks(rotation=45,fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel("District",fontsize=16)
plt.ylabel("Average family size",fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# 19. Create a horizontal bar chart for Top 15 Local Levels with highest Sex Ratio imbalance.

# %%
# 1. Find the top 10 districts by looking at the head(10) names
top_sex_ratio_list = data.sort_values(by='Sex Ration', ascending=False).head(15)['Local Level Name'].unique()

# 2. Filter the ORIGINAL dataset to include ALL rows belonging to those districts
sex_ratio_data = data[data['Local Level Name'].isin(top_sex_ratio_list)]

plt.figure(figsize=(15, 10))
sns.barplot(
    data=sex_ratio_data,
    x='Sex Ration', 
    y='Local Level Name',
    palette='viridis'
)
plt.xlabel("Sex Ration", fontsize=16)
plt.ylabel("Local Level Name", fontsize=16)
plt.title("Top 15 Local Level Name with highest Sex Ratio",fontsize=16)
plt.show
# Out:
# /var/folders/d8/83r4k_r15tv7zl64z94ffs640000gn/T/ipykernel_18086/96543234.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Gharajhong Rural Municipality has the highest sex ration.

# %% [markdown]
# 20. Use a heatmap to show correlation between all numerical variables (Population, Male, Female, Families, Households).

# %%
data.sample()
# Out:
#      _id    District              Local Level Name  Total family number  \
# 732  733  Dadeldhura  Nawadurga Rural Municipality                 4335
#
#      Total household number  Total population  Total Male  Total Female  \
# 732                    3634             18745        8194         10551
#
#      mismatch  Male percentage  Female percentage  Sex Ration  \
# 732      True            43.71              56.29        0.78
#
#      population density  Average family size  Average household size
# 732            5.158228                 4.32                    5.16

# %%
data[['Total population','Total Male','Total Female','Total family number','Total household number']].corr()
# Out:
#                         Total population  Total Male  Total Female  \
# Total population                1.000000    0.299844      0.315339
# Total Male                      0.299844    1.000000      0.997284
# Total Female                    0.315339    0.997284      1.000000
# Total family number             0.253037    0.987539      0.989928
# Total household number          0.815717    0.256059      0.273940
#
#                         Total family number  Total household number
# Total population                   0.253037                0.815717
# Total Male                         0.987539                0.256059
# Total Female                       0.989928                0.273940
# Total family number                1.000000                0.236384
# Total household number             0.236384                1.000000

# %%
sns.heatmap(data[['Total population','Total Male','Total Female','Total family number','Total household number']].corr())
# Out:
# <Axes: >

# %%
data.to_csv('census_data_eda.csv', index=False)

# %% [markdown]
# !!! EDA Project Completed !!!!!

# %% [markdown]
# connecting to the postgresql server

# %%
import psycopg2

# %%
# Connect to PostgreSQL database
def connect_with_psycopg2():
    try:
        # Database connection parameters
        connection = psycopg2.connect(
            host="localhost",        # or your server IP
            database="EDA projects", # replace with your database name
            user="postgres",    # replace with your username
            password="bikash", # replace with your password
            port="5432"              # default PostgreSQL port
        )
    
        print("Connection to PostgreSQL database successful.")
        return connection
    except Exception as e:
        print("Error while connecting to PostgreSQL database:", e)
        return None
# Example usage
connection = connect_with_psycopg2()
# Out:
# Connection to PostgreSQL database successful.

# %%
# Load CSV into PostgreSQL
from sqlalchemy import create_engine
import pandas as pd
def load_csv_to_postgres(csv_file, table_name):
    try:
        # Read the CSV file
        df = pd.read_csv(csv_file)
        
        # Create SQLAlchemy engine from psycopg2 connection
        connection = connect_with_psycopg2()
        if connection is None:
            return
        
        engine = create_engine('postgresql://postgres:bikash@localhost:5432/EDA projects')
        
        # Load DataFrame to PostgreSQL
        df.to_sql(table_name, engine, index=False, if_exists='replace')
        print(f"CSV file {csv_file} loaded into table {table_name} successfully.")
        
        # Close the connection
        connection.close()
    except Exception as e:
        print("Error while loading CSV to PostgreSQL:", e)

# Example usage
csv_file = "census_data_eda.csv"  # Path to your CSV file
table_name = "cleaned_census_data"    # Desired table name in PostgreSQL
load_csv_to_postgres(csv_file, table_name)
# Out:
# Connection to PostgreSQL database successful.
# CSV file census_data_eda.csv loaded into table cleaned_census_data successfully.
